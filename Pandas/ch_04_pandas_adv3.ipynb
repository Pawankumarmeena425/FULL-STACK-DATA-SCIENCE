# %%
import pandas as pd

# %%
df =  pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# deleate column
df.drop('PassengerId',axis=1)
# axis =0 ,means row access and axis =1 means column access
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
# but it is not happen for parmanently
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# first method assign new dataframe to df
# df =df.drop('PassengerId',axis=1)
# df

# %%
# 2nd way --->> inplace = True
df.drop('PassengerId',axis=1,inplace = True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
# how to delete row 
df.drop(3,inplace = True)
# axis by defualt is 0

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
# how to make some column to the row index
df.set_index('Name',inplace = True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
# ...                                                  ...    ...    ...
# Montvila, Rev. Juozas                               27.0      0      0
# Graham, Miss. Margaret Edith                        19.0      0      0
# Johnston, Miss. Catherine Helen "Carrie"             NaN      1      2
# Behr, Mr. Karl Howell                               26.0      0      0
# Dooley, Mr. Patrick                                 32.0      0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Allen, Mr. William Henry                             NaN        S
# Moran, Mr. James                                     NaN        Q
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [890 rows x 10 columns]

# %%
df.reset_index()
# it make index to by default
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      male  35.0      0      0            373450   8.0500   NaN        S
# 4      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885    male  27.0      0      0            211536  13.0000   NaN        S
# 886  female  19.0      0      0            112053  30.0000   B42        S
# 887  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0            111369  30.0000  C148        C
# 889    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
d = {
    'key1':  [2,3,4,6,7,8],
    'key2' : [9,7,5,3,8,8],
    'key3' : [6,4,2,7,8,4]
    }

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     9     6
# 1     3     7     4
# 2     4     5     2
# 3     6     3     7
# 4     7     8     8
# 5     8     8     4

# %%
df1 = pd.read_csv("taxonomy.csv")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna(inplace = True)
# it will delete rows which have no data

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis = 1, inplace =  True)
# no value will be deleted , because missing row already deleted

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df2 = pd.read_csv("taxonomy.csv")

# %%
df2.dropna(axis =1)
# it delete those column which have null or missing value
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df2.fillna("sudh")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency      sudh                  sudh
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df2.fillna("sudh",inplace = True)
# now missing value fill with sudh , and now if we wnat to dropna use no column will be deleted

# %%
df2.dropna(axis = 1)
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency      sudh                  sudh
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Allen, Mr. William Henry                            35.0      0      0
# Moran, Mr. James                                     NaN      0      0
# ...                                                  ...    ...    ...
# Montvila, Rev. Juozas                               27.0      0      0
# Graham, Miss. Margaret Edith                        19.0      0      0
# Johnston, Miss. Catherine Helen "Carrie"             NaN      1      2
# Behr, Mr. Karl Howell                               26.0      0      0
# Dooley, Mr. Patrick                                 32.0      0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Allen, Mr. William Henry                                      373450   8.0500
# Moran, Mr. James                                              330877   8.4583
# ...                                                              ...      ...
# Montvila, Rev. Juozas                                         211536  13.0000
# Graham, Miss. Margaret Edith                                  112053  30.0000
# Johnston, Miss. Catherine Helen "Carrie"                  W./C. 6607  23.4500
# Behr, Mr. Karl Howell                                         111369  30.0000
# Dooley, Mr. Patrick                                           370376   7.7500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Allen, Mr. William Henry                             NaN        S
# Moran, Mr. James                                     NaN        Q
# ...                                                  ...      ...
# Montvila, Rev. Juozas                                NaN        S
# Graham, Miss. Margaret Edith                         B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN        S
# Behr, Mr. Karl Howell                               C148        C
# Dooley, Mr. Patrick                                  NaN        Q
#
# [890 rows x 10 columns]

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      male  35.0      0      0            373450   8.0500   NaN        S
# 4      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885    male  27.0      0      0            211536  13.0000   NaN        S
# 886  female  19.0      0      0            112053  30.0000   B42        S
# 887  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0            111369  30.0000  C148        C
# 889    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
# how to group base on some value or key
g = df.groupby('Survived')

# %%
g

# %%
g.sum()
# sum of all the value base on group saperated
# Out:
# /tmp/ipykernel_1079/1656072996.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1390  12985.50    304    181  12142.7199
# 1            666   8184.67    161    159  16498.1294

# %%
g.mean()
# Out:
# /tmp/ipykernel_1079/2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.953079  28.320657  0.472141  0.466276  48.381611

# %%
g1 = df.groupby("Pclass")

# %%
g1

# %%
g1.sum()
# Out:
# /tmp/ipykernel_1079/2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            135  7076.42     89     77  18124.3125
# 2             87  5168.83     74     70   3801.8417
# 3            119  8924.92    302    193   6714.6951

# %%
g1.mean()
# Out:
# /tmp/ipykernel_1079/3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#         Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       0.627907  38.250919  0.413953  0.358140  84.299128
# 2       0.472826  29.877630  0.402174  0.380435  20.662183
# 3       0.242363  25.140620  0.615071  0.393075  13.675550

# %%
g1.max()
# Out:
# /tmp/ipykernel_1079/130714741.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()
#                                Name  Survived   Sex   Age  SibSp  Parch  \
# Pclass
# 1          Young, Miss. Marie Grice         1  male  80.0      3      4
# 2         del Carlo, Mr. Sebastiano         1  male  70.0      3      3
# 3       van Melkebeke, Mr. Philemon         1  male  74.0      8      6
#
#             Ticket      Fare
# Pclass
# 1        WE/P 5735  512.3292
# 2        W/C 14208   73.5000
# 3       W./C. 6609   69.5500

# %%
g1.max()['Fare']
# Out:
# /tmp/ipykernel_1079/730728694.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()['Fare']
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
g1.max().T
# it rotate value by 180 degree
# Out:
# /tmp/ipykernel_1079/2755232466.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().T
# Pclass                           1                          2  \
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# Name      van Melkebeke, Mr. Philemon
# Survived                            1
# Sex                              male
# Age                              74.0
# SibSp                               8
# Parch                               6
# Ticket                     W./C. 6609
# Fare                            69.55

# %%
df.T
# Out:
#                               0    \
# Name      Braund, Mr. Owen Harris
# Survived                        0
# Pclass                          3
# Sex                          male
# Age                          22.0
# SibSp                           1
# Parch                           0
# Ticket                  A/5 21171
# Fare                         7.25
# Cabin                         NaN
# Embarked                        S
#
#                                                         1    \
# Name      Cumings, Mrs. John Bradley (Florence Briggs Th...
# Survived                                                  1
# Pclass                                                    1
# Sex                                                  female
# Age                                                    38.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                             PC 17599
# Fare                                                71.2833
# Cabin                                                   C85
# Embarked                                                  C
#
#                              2                         3                 4    \
# Name      Heikkinen, Miss. Laina  Allen, Mr. William Henry  Moran, Mr. James
# Survived                       1                         0                 0
# Pclass                         3                         3                 3
# Sex                       female                      male              male
# Age                         26.0                      35.0               NaN
# SibSp                          0                         0                 0
# Parch                          0                         0                 0
# Ticket          STON/O2. 3101282                    373450            330877
# Fare                       7.925                      8.05            8.4583
# Cabin                        NaN                       NaN               NaN
# Embarked                       S                         S                 Q
#
#                               5                               6    \
# Name      McCarthy, Mr. Timothy J  Palsson, Master. Gosta Leonard
# Survived                        0                               0
# Pclass                          1                               3
# Sex                          male                            male
# Age                          54.0                             2.0
# SibSp                           0                               3
# Parch                           0                               1
# Ticket                      17463                          349909
# Fare                      51.8625                          21.075
# Cabin                         E46                             NaN
# Embarked                        S                               S
#
#                                                         7    \
# Name      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Survived                                                  1
# Pclass                                                    3
# Sex                                                  female
# Age                                                    27.0
# SibSp                                                     0
# Parch                                                     2
# Ticket                                               347742
# Fare                                                11.1333
# Cabin                                                   NaN
# Embarked                                                  S
#
#                                           8    \
# Name      Nasser, Mrs. Nicholas (Adele Achem)
# Survived                                    1
# Pclass                                      2
# Sex                                    female
# Age                                      14.0
# SibSp                                       1
# Parch                                       0
# Ticket                                 237736
# Fare                                  30.0708
# Cabin                                     NaN
# Embarked                                    C
#
#                                       9    ...                 880  \
# Name      Sandstrom, Miss. Marguerite Rut  ...  Markun, Mr. Johann
# Survived                                1  ...                   0
# Pclass                                  3  ...                   3
# Sex                                female  ...                male
# Age                                   4.0  ...                33.0
# SibSp                                   1  ...                   0
# Parch                                   1  ...                   0
# Ticket                            PP 9549  ...              349257
# Fare                                 16.7  ...              7.8958
# Cabin                                  G6  ...                 NaN
# Embarked                                S  ...                   S
#
#                                    881                            882  \
# Name      Dahlberg, Miss. Gerda Ulrika  Banfield, Mr. Frederick James
# Survived                             0                              0
# Pclass                               3                              2
# Sex                             female                           male
# Age                               22.0                           28.0
# SibSp                                0                              0
# Parch                                0                              0
# Ticket                            7552               C.A./SOTON 34068
# Fare                           10.5167                           10.5
# Cabin                              NaN                            NaN
# Embarked                             S                              S
#
#                              883                                   884  \
# Name      Sutehall, Mr. Henry Jr  Rice, Mrs. William (Margaret Norton)
# Survived                       0                                     0
# Pclass                         3                                     3
# Sex                         male                                female
# Age                         25.0                                  39.0
# SibSp                          0                                     0
# Parch                          0                                     5
# Ticket           SOTON/OQ 392076                                382652
# Fare                        7.05                                29.125
# Cabin                        NaN                                   NaN
# Embarked                       S                                     Q
#
#                             885                           886  \
# Name      Montvila, Rev. Juozas  Graham, Miss. Margaret Edith
# Survived                      0                             1
# Pclass                        2                             1
# Sex                        male                        female
# Age                        27.0                          19.0
# SibSp                         0                             0
# Parch                         0                             0
# Ticket                   211536                        112053
# Fare                       13.0                          30.0
# Cabin                       NaN                           B42
# Embarked                      S                             S
#
#                                                887                    888  \
# Name      Johnston, Miss. Catherine Helen "Carrie"  Behr, Mr. Karl Howell
# Survived                                         0                      1
# Pclass                                           3                      1
# Sex                                         female                   male
# Age                                            NaN                   26.0
# SibSp                                            1                      0
# Parch                                            2                      0
# Ticket                                  W./C. 6607                 111369
# Fare                                         23.45                   30.0
# Cabin                                          NaN                   C148
# Embarked                                         S                      C
#
#                           889
# Name      Dooley, Mr. Patrick
# Survived                    0
# Pclass                      3
# Sex                      male
# Age                      32.0
# SibSp                       0
# Parch                       0
# Ticket                 370376
# Fare                     7.75
# Cabin                     NaN
# Embarked                    Q
#
# [11 rows x 890 columns]

# %%
g1.max().transpose()
# Out:
# /tmp/ipykernel_1079/3907411846.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().transpose()
# Pclass                           1                          2  \
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# Name      van Melkebeke, Mr. Philemon
# Survived                            1
# Sex                              male
# Age                              74.0
# SibSp                               8
# Parch                               6
# Ticket                     W./C. 6609
# Fare                            69.55

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      male  35.0      0      0            373450   8.0500   NaN        S
# 4      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885    male  27.0      0      0            211536  13.0000   NaN        S
# 886  female  19.0      0      0            112053  30.0000   B42        S
# 887  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0            111369  30.0000  C148        C
# 889    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
df5 = df[['Name','Survived','Pclass']][0:5]

# %%
df6 = df[['Name','Survived','Pclass']][5:10]

# %%
df5
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3

# %%
df6
# Out:
#                                                 Name  Survived  Pclass
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
# how to concate both dataframe
pd.concat([df5,df6])
# by default it concanate to verticle(row wise)
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
df7 = pd.concat([df5,df6],axis = 1)
# horizontal concationation

# %%
df7
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris       0.0     3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1.0     1.0
# 2                             Heikkinen, Miss. Laina       1.0     3.0
# 3                           Allen, Mr. William Henry       0.0     3.0
# 4                                   Moran, Mr. James       0.0     3.0
# 5                                                NaN       NaN     NaN
# 6                                                NaN       NaN     NaN
# 7                                                NaN       NaN     NaN
# 8                                                NaN       NaN     NaN
# 9                                                NaN       NaN     NaN
#
#                                                 Name  Survived  Pclass
# 0                                                NaN       NaN     NaN
# 1                                                NaN       NaN     NaN
# 2                                                NaN       NaN     NaN
# 3                                                NaN       NaN     NaN
# 4                                                NaN       NaN     NaN
# 5                            McCarthy, Mr. Timothy J       0.0     1.0
# 6                     Palsson, Master. Gosta Leonard       0.0     3.0
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       1.0     3.0
# 8                Nasser, Mrs. Nicholas (Adele Achem)       1.0     2.0
# 9                    Sandstrom, Miss. Marguerite Rut       1.0     3.0

# %%
df7.fillna("pawan")
# Out:
#                                                 Name Survived Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0    3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0    1.0
# 2                             Heikkinen, Miss. Laina      1.0    3.0
# 3                           Allen, Mr. William Henry      0.0    3.0
# 4                                   Moran, Mr. James      0.0    3.0
# 5                                              pawan    pawan  pawan
# 6                                              pawan    pawan  pawan
# 7                                              pawan    pawan  pawan
# 8                                              pawan    pawan  pawan
# 9                                              pawan    pawan  pawan
#
#                                                 Name Survived Pclass
# 0                                              pawan    pawan  pawan
# 1                                              pawan    pawan  pawan
# 2                                              pawan    pawan  pawan
# 3                                              pawan    pawan  pawan
# 4                                              pawan    pawan  pawan
# 5                            McCarthy, Mr. Timothy J      0.0    1.0
# 6                     Palsson, Master. Gosta Leonard      0.0    3.0
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      1.0    3.0
# 8                Nasser, Mrs. Nicholas (Adele Achem)      1.0    2.0
# 9                    Sandstrom, Miss. Marguerite Rut      1.0    3.0

# %%
data1 = pd.DataFrame({
    'key1':[3,5,6,8,9,4],
    'key2':[7,8,4,3,0,6],
    'key3':[9,6,4,3,5,7]
   })

# %%
data1
# Out:
#    key1  key2  key3
# 0     3     7     9
# 1     5     8     6
# 2     6     4     4
# 3     8     3     3
# 4     9     0     5
# 5     4     6     7

# %%
data2 = pd.DataFrame({
    'key1':[3,5,34,34,9,4],
    'key4':[7,8,423,43,23,53],
    'key5':[9,6,43,323,5,7]
   })

# %%
data2
# Out:
#    key1  key4  key5
# 0     3     7     9
# 1     5     8     6
# 2    34   423    43
# 3    34    43   323
# 4     9    23     5
# 5     4    53     7

# %%
pd.merge(data1,data2)
# by default it merege data base on inner means base on common column in both datafram . Then check comman column value is persent is both datafram then it print that row by mergeing rest data
# Out:
#    key1  key2  key3  key4  key5
# 0     3     7     9     7     9
# 1     5     8     6     8     6
# 2     9     0     5    23     5
# 3     4     6     7    53     7

# %%
pd.merge(data1,data2,how = 'left')
# Out:
#    key1  key2  key3  key4  key5
# 0     3     7     9   7.0   9.0
# 1     5     8     6   8.0   6.0
# 2     6     4     4   NaN   NaN
# 3     8     3     3   NaN   NaN
# 4     9     0     5  23.0   5.0
# 5     4     6     7  53.0   7.0

# %%
pd.merge(data1,data2,how = 'right')
# Out:
#    key1  key2  key3  key4  key5
# 0     3   7.0   9.0     7     9
# 1     5   8.0   6.0     8     6
# 2    34   NaN   NaN   423    43
# 3    34   NaN   NaN    43   323
# 4     9   0.0   5.0    23     5
# 5     4   6.0   7.0    53     7

# %%
pd.merge(data1,data2,how = 'outer')
# Out:
#    key1  key2  key3   key4   key5
# 0     3   7.0   9.0    7.0    9.0
# 1     5   8.0   6.0    8.0    6.0
# 2     6   4.0   4.0    NaN    NaN
# 3     8   3.0   3.0    NaN    NaN
# 4     9   0.0   5.0   23.0    5.0
# 5     4   6.0   7.0   53.0    7.0
# 6    34   NaN   NaN  423.0   43.0
# 7    34   NaN   NaN   43.0  323.0

# %%
pd.merge(data1,data2,how = 'outer',on = 'key1')
# Out:
#    key1  key2  key3   key4   key5
# 0     3   7.0   9.0    7.0    9.0
# 1     5   8.0   6.0    8.0    6.0
# 2     6   4.0   4.0    NaN    NaN
# 3     8   3.0   3.0    NaN    NaN
# 4     9   0.0   5.0   23.0    5.0
# 5     4   6.0   7.0   53.0    7.0
# 6    34   NaN   NaN  423.0   43.0
# 7    34   NaN   NaN   43.0  323.0

# %%
pd.merge(data1,data2,how = 'cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        3     7     9       3     7     9
# 1        3     7     9       5     8     6
# 2        3     7     9      34   423    43
# 3        3     7     9      34    43   323
# 4        3     7     9       9    23     5
# 5        3     7     9       4    53     7
# 6        5     8     6       3     7     9
# 7        5     8     6       5     8     6
# 8        5     8     6      34   423    43
# 9        5     8     6      34    43   323
# 10       5     8     6       9    23     5
# 11       5     8     6       4    53     7
# 12       6     4     4       3     7     9
# 13       6     4     4       5     8     6
# 14       6     4     4      34   423    43
# 15       6     4     4      34    43   323
# 16       6     4     4       9    23     5
# 17       6     4     4       4    53     7
# 18       8     3     3       3     7     9
# 19       8     3     3       5     8     6
# 20       8     3     3      34   423    43
# 21       8     3     3      34    43   323
# 22       8     3     3       9    23     5
# 23       8     3     3       4    53     7
# 24       9     0     5       3     7     9
# 25       9     0     5       5     8     6
# 26       9     0     5      34   423    43
# 27       9     0     5      34    43   323
# 28       9     0     5       9    23     5
# 29       9     0     5       4    53     7
# 30       4     6     7       3     7     9
# 31       4     6     7       5     8     6
# 32       4     6     7      34   423    43
# 33       4     6     7      34    43   323
# 34       4     6     7       9    23     5
# 35       4     6     7       4    53     7

# %%
# how to give index kudse
data1 = pd.DataFrame({
    'key1':[3,5,6,8,9,4],
    'key2':[7,8,4,3,0,6],
    'key3':[9,6,4,3,5,7]
   }, 
    index = ['a','b','c','d','e','f']
)

# %%
data2 = pd.DataFrame({
    'key6':[3,5,34,34,9,4],
    'key4':[7,8,423,43,23,53],
    'key5':[9,6,43,323,5,7]
   },index = ['a','b','h','i','j','k'])

# %%
data1
# Out:
#    key1  key2  key3
# a     3     7     9
# b     5     8     6
# c     6     4     4
# d     8     3     3
# e     9     0     5
# f     4     6     7

# %%
data2
# Out:
#    key6  key4  key5
# a     3     7     9
# b     5     8     6
# h    34   423    43
# i    34    43   323
# j     9    23     5
# k     4    53     7

# %%
data1.join(data2)
# **************join function  work on index while merge function work on column*******************
# Out:
#    key1  key2  key3  key6  key4  key5
# a     3     7     9   3.0   7.0   9.0
# b     5     8     6   5.0   8.0   6.0
# c     6     4     4   NaN   NaN   NaN
# d     8     3     3   NaN   NaN   NaN
# e     9     0     5   NaN   NaN   NaN
# f     4     6     7   NaN   NaN   NaN

# %%
data1.join(data2,how = 'right')
# Out:
#    key1  key2  key3  key6  key4  key5
# a   3.0   7.0   9.0     3     7     9
# b   5.0   8.0   6.0     5     8     6
# h   NaN   NaN   NaN    34   423    43
# i   NaN   NaN   NaN    34    43   323
# j   NaN   NaN   NaN     9    23     5
# k   NaN   NaN   NaN     4    53     7

# %%
data1.join(data2,how = 'inner')
# Out:
#    key1  key2  key3  key6  key4  key5
# a     3     7     9     3     7     9
# b     5     8     6     5     8     6

# %%
data1.join(data2,how = 'outer')
# Out:
#    key1  key2  key3  key6   key4   key5
# a   3.0   7.0   9.0   3.0    7.0    9.0
# b   5.0   8.0   6.0   5.0    8.0    6.0
# c   6.0   4.0   4.0   NaN    NaN    NaN
# d   8.0   3.0   3.0   NaN    NaN    NaN
# e   9.0   0.0   5.0   NaN    NaN    NaN
# f   4.0   6.0   7.0   NaN    NaN    NaN
# h   NaN   NaN   NaN  34.0  423.0   43.0
# i   NaN   NaN   NaN  34.0   43.0  323.0
# j   NaN   NaN   NaN   9.0   23.0    5.0
# k   NaN   NaN   NaN   4.0   53.0    7.0

# %%
data1.join(data2,how = 'cross')
# Out:
#     key1  key2  key3  key6  key4  key5
# 0      3     7     9     3     7     9
# 1      3     7     9     5     8     6
# 2      3     7     9    34   423    43
# 3      3     7     9    34    43   323
# 4      3     7     9     9    23     5
# 5      3     7     9     4    53     7
# 6      5     8     6     3     7     9
# 7      5     8     6     5     8     6
# 8      5     8     6    34   423    43
# 9      5     8     6    34    43   323
# 10     5     8     6     9    23     5
# 11     5     8     6     4    53     7
# 12     6     4     4     3     7     9
# 13     6     4     4     5     8     6
# 14     6     4     4    34   423    43
# 15     6     4     4    34    43   323
# 16     6     4     4     9    23     5
# 17     6     4     4     4    53     7
# 18     8     3     3     3     7     9
# 19     8     3     3     5     8     6
# 20     8     3     3    34   423    43
# 21     8     3     3    34    43   323
# 22     8     3     3     9    23     5
# 23     8     3     3     4    53     7
# 24     9     0     5     3     7     9
# 25     9     0     5     5     8     6
# 26     9     0     5    34   423    43
# 27     9     0     5    34    43   323
# 28     9     0     5     9    23     5
# 29     9     0     5     4    53     7
# 30     4     6     7     3     7     9
# 31     4     6     7     5     8     6
# 32     4     6     7    34   423    43
# 33     4     6     7    34    43   323
# 34     4     6     7     9    23     5
# 35     4     6     7     4    53     7

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      male  35.0      0      0            373450   8.0500   NaN        S
# 4      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885    male  27.0      0      0            211536  13.0000   NaN        S
# 886  female  19.0      0      0            112053  30.0000   B42        S
# 887  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0            111369  30.0000  C148        C
# 889    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [890 rows x 11 columns]

# %%
# how to convert fare  eru to ruppes and add new column of ruppes
df['Fare_INR']  =df['Fare'].apply(lambda x : x*80)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      male  35.0      0      0            373450   8.0500   NaN        S
# 4      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885    male  27.0      0      0            211536  13.0000   NaN        S
# 886  female  19.0      0      0            112053  30.0000   B42        S
# 887  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0            111369  30.0000  C148        C
# 889    male  32.0      0      0            370376   7.7500   NaN        Q
#
#      Fare_INR
# 0     580.000
# 1    5702.664
# 2     634.000
# 3     644.000
# 4     676.664
# ..        ...
# 885  1040.000
# 886  2400.000
# 887  1876.000
# 888  2400.000
# 889   620.000
#
# [890 rows x 12 columns]

# %%
def  age_add(x):
    return x+5

df['Age_add'] = df['Age'].apply(age_add)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      male  35.0      0      0            373450   8.0500   NaN        S
# 4      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885    male  27.0      0      0            211536  13.0000   NaN        S
# 886  female  19.0      0      0            112053  30.0000   B42        S
# 887  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0            111369  30.0000  C148        C
# 889    male  32.0      0      0            370376   7.7500   NaN        Q
#
#      Fare_INR  Age_add
# 0     580.000     27.0
# 1    5702.664     43.0
# 2     634.000     31.0
# 3     644.000     40.0
# 4     676.664      NaN
# ..        ...      ...
# 885  1040.000     32.0
# 886  2400.000     24.0
# 887  1876.000      NaN
# 888  2400.000     31.0
# 889   620.000     37.0
#
# [890 rows x 13 columns]

# %%
# calculate lengeth of the name and store in new column
df['name_len'] = df['Name'].apply(len)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      male  35.0      0      0            373450   8.0500   NaN        S
# 4      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885    male  27.0      0      0            211536  13.0000   NaN        S
# 886  female  19.0      0      0            112053  30.0000   B42        S
# 887  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0            111369  30.0000  C148        C
# 889    male  32.0      0      0            370376   7.7500   NaN        Q
#
#      Fare_INR  Age_add  name_len
# 0     580.000     27.0        23
# 1    5702.664     43.0        51
# 2     634.000     31.0        22
# 3     644.000     40.0        24
# 4     676.664      NaN        16
# ..        ...      ...       ...
# 885  1040.000     32.0        21
# 886  2400.000     24.0        28
# 887  1876.000      NaN        40
# 888  2400.000     31.0        21
# 889   620.000     37.0        19
#
# [890 rows x 14 columns]

# %%
# write where fare less then 10 cheap , 10 to 20 mid and grater then 20 is high
def cat_fare(x):
    if x<10:
        return "cheap"
    elif x>=10 and x<20:
        return "mid"
    else :
        return "high"

# %%
df['cat_fare'] = df['Fare'].apply(cat_fare)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      male  35.0      0      0            373450   8.0500   NaN        S
# 4      male   NaN      0      0            330877   8.4583   NaN        Q
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 885    male  27.0      0      0            211536  13.0000   NaN        S
# 886  female  19.0      0      0            112053  30.0000   B42        S
# 887  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 888    male  26.0      0      0            111369  30.0000  C148        C
# 889    male  32.0      0      0            370376   7.7500   NaN        Q
#
#      Fare_INR  Age_add  name_len cat_fare
# 0     580.000     27.0        23    cheap
# 1    5702.664     43.0        51     high
# 2     634.000     31.0        22    cheap
# 3     644.000     40.0        24    cheap
# 4     676.664      NaN        16    cheap
# ..        ...      ...       ...      ...
# 885  1040.000     32.0        21      mid
# 886  2400.000     24.0        28     high
# 887  1876.000      NaN        40     high
# 888  2400.000     31.0        21     high
# 889   620.000     37.0        19    cheap
#
# [890 rows x 15 columns]
