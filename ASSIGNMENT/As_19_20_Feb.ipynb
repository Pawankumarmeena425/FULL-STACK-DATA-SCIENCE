# %%
pip install Flask
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 31.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Q1. Explain GET and POST methods.

# GET Methods : GET methods use to send the data through the url to the server , when client requent to send the data through the url ot it will send through the get method by default.
from flask import Flask

app = Flask(__name__)

@app.route("/hello")
def hello_world():
    return "<h1>Hello, World!</h1>"

if __name__=="__main__":
    app.run(host="0.0.0.0",port=4000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:4000
#  * Running on http://172.18.0.3:4000
# Press CTRL+C to quit

# %%
# POST Methods : POST method use to send data through the some body , form or some Http pages. It will be send by passing POST as a paremeter in the route decorator.
@app.route('/math',methods=['POST'])
def math_operation():
    if(request.method=='POST'):
        ops = request.form['operation']
        num1 = int(request.form['num1'])
        num2 = int(request.form['num2'])

# %%
# Q2. Why is request used in Flask?

'''when client requent to send data in the form of the http page then request object is use to send . request object  contains information about the request such as the URL, headers, data, and other relevant details.
The request object in Flask provides a convenient way for developers to access the http form  information'''

# %%
# Q3. Why is redirect() used in Flask?

'''  
The redirect() function in Flask is used to redirect the user's web browser to a different URL. This function is useful when we want to send the user to a different
page or route within your Flask application or to a completely different website.
''''

# %%
# Q4. What are templates in Flask? Why is the render_template() function used?

# Templetes : In Flask, templates are files that contain HTML, CSS, and other static content along with dynamic placeholders, which are replaced by actual data at runtime. Templates are used to generate dynamic content for web pages in response to user requests.

# -->> The render_template() function in Flask is used to render a specified template and return the resulting HTML content to the client

# %%
# Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

from flask import Flask,render_template,request,jsonify

app = Flask(__name__)

@app.route("/pawan",methods = ['POST'])
def postman_api():
     if(request.method=='POST'):
        ops = request.json['operation']
        b = int(request.json['breadth'])
        l = int(request.json['length'])
        
        if(ops=='area'):
            area = l*b
            result = "The area of the given input is : "+ (str)(area)
            return jsonify(result)
            
            

if __name__=="__main__":
    app.run(host="0.0.0.0",port=7000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:7000
#  * Running on http://172.18.0.32:7000
# Press CTRL+C to quit
# 172.18.0.2 - - [15/Mar/2023 16:22:45] "POST /pawan HTTP/1.1" 200 -

# %% [markdown]
# # output :
# ![Screenshot (205).png](attachment:d4ea24cb-fd49-4f05-b5c6-064b40bb6490.png)
